# %%
import detect_edges
from keras.models import load_model
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
unet = load_model('unet2.keras')

# %%
YOUR_IMAGE = 'TOY.jpg'

plt.imshow(detect_edges.predict_custom_image(YOUR_IMAGE, model=unet))
